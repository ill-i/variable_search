# %% [markdown]
# # Libraries

# %%
# Data handling
import pandas as pd  # For working with tabular data (DataFrames), e.g., storing and manipulating source catalogs

# Astrometry and coordinate matching
from astropy.coordinates import SkyCoord, match_coordinates_sky  # For celestial coordinate manipulation and cross-matching of sources
import astropy.units as u  # For handling physical units (e.g., degrees, arcseconds)

# FITS file support
from astropy.io import fits  # To read/write FITS files (standard format for astronomical data)
from astropy.table import Table  # For working with structured data tables, often used in FITS extensions

# Numerical computations
import numpy as np  # For array operations and efficient numerical processing

# %% [markdown]
# # Functions

# %% [markdown]
# ## Catalogue

# %%
def filter_catalog_by_coordinates(frame_df, catalog_df):
    """
    Filters a large reference catalog based on the coordinate range from detected sources in a frame.

    Parameters:
    - frame_df : pandas.DataFrame
        DataFrame with sources detected in an image frame (must contain 'ra' and 'dec' columns).
    - catalog_df : pandas.DataFrame
        Large reference catalog containing 'ra' and 'dec' columns.

    Returns:
    - filtered_catalog : pandas.DataFrame
        Catalog entries within the RA/Dec bounds defined by the frame.
    """
    ra_min, ra_max = frame_df['ra'].min(), frame_df['ra'].max()
    dec_min, dec_max = frame_df['dec'].min(), frame_df['dec'].max()

    filtered_catalog = catalog_df[
        (catalog_df['ra'] >= ra_min) & (catalog_df['ra'] <= ra_max) &
        (catalog_df['dec'] >= dec_min) & (catalog_df['dec'] <= dec_max)
    ]
    return filtered_catalog


def match_objects_and_catalog(frame_df, catalog_df, output_path, unmatched_output_path, radius):
    """
    Cross-matches sources detected in a frame with a reference catalog using sky coordinates.

    Outputs two tables:
    1. Matched sources with appended catalog data and coordinate offsets.
    2. Unmatched sources where the nearest neighbor lies beyond the matching radius.

    Parameters:
    - frame_df : pandas.DataFrame
        DataFrame with detected objects in the frame ('ra', 'dec' required).
    - catalog_df : pandas.DataFrame
        Pre-filtered reference catalog (must contain 'ra', 'dec').
    - output_path : str
        File path to save matched sources with appended catalog data.
    - unmatched_output_path : str
        File path to save unmatched sources.
    - radius : float
        Maximum allowed separation in arcseconds for a match to be considered valid.

    Returns:
    - matched_frame : pandas.DataFrame
        DataFrame containing matched objects and catalog information.
    - unmatched_frame : pandas.DataFrame
        DataFrame of unmatched objects (those with separation > radius).
    """
    frame_coords = SkyCoord(ra=frame_df['ra'].values * u.deg, dec=frame_df['dec'].values * u.deg)
    catalog_coords = SkyCoord(ra=catalog_df['ra'].values * u.deg, dec=catalog_df['dec'].values * u.deg)

    idx, d2d, _ = match_coordinates_sky(frame_coords, catalog_coords)

    frame_df = frame_df.add_suffix('_frame')
    matched_frame = frame_df.copy()

    for col in catalog_df.columns:
        matched_frame[col + '_cat'] = catalog_df.iloc[idx][col].values

    matched_frame['coord_diff_arcsec'] = d2d.arcsec
    matched_frame['match_status'] = ['uncertain' if diff > radius else 'matched' for diff in d2d.arcsec]

    matched_frame.to_csv(output_path, index=False)

    unmatched_mask = d2d.arcsec > radius
    unmatched_frame = frame_df[unmatched_mask]
    unmatched_frame.to_csv(unmatched_output_path, index=False)

    return matched_frame, unmatched_frame

def create_fits_with_metadata(matched_frame, catalog_fits_path, output_fits_path):
    """
    Creates a FITS table with metadata, combining matched frame data and reference catalog entries.

    Column metadata is populated using:
    - Descriptions for frame-derived columns.
    - FITS header comments for catalog columns (when available).

    Parameters:
    - matched_frame : pandas.DataFrame
        Table of matched sources with both frame and catalog data.
    - catalog_fits_path : str
        Path to the original reference catalog FITS file (used to extract metadata).
    - output_fits_path : str
        Output path to save the resulting FITS file with column metadata.
    """
    table = Table.from_pandas(matched_frame)

    with fits.open(catalog_fits_path) as hdul:
        catalog_header = hdul[1].header

    # Metadata for frame-derived columns
    metadata_frame = {
        'id_frame': {'description': 'Object identifier', 'unit': ''},
        'x_frame': {'description': 'X coordinate on image', 'unit': 'pixels'},
        'y_frame': {'description': 'Y coordinate on image', 'unit': 'pixels'},
        'ra_frame': {'description': 'Right ascension of object', 'unit': 'degrees'},
        'dec_frame': {'description': 'Declination of object', 'unit': 'degrees'},
        'flux_frame': {'description': 'Flux of object', 'unit': 'arbitrary units'},
        'flux_err_frame': {'description': 'Flux error', 'unit': 'arbitrary units'},
        'mag_frame': {'description': 'Magnitude of object', 'unit': 'mag'},
        'mag_err_frame': {'description': 'Magnitude error', 'unit': 'mag'},
        'flag_frame': {'description': 'Quality flags', 'unit': ''},
        'a_frame': {'description': 'Semi-major axis', 'unit': 'pixels'},
        'b_frame': {'description': 'Semi-minor axis', 'unit': 'pixels'},
        'coord_diff_arcsec': {'description': 'Coordinate difference between frame and catalog', 'unit': 'arcsec'}
    }

    for col in metadata_frame:
        if col in table.colnames:
            table[col].description = metadata_frame[col]['description']
            table[col].unit = metadata_frame[col]['unit']

    for col in catalog_header:
        cat_col_name = col + '_cat'
        if cat_col_name in table.colnames:
            table[cat_col_name].description = catalog_header.comments.get(col, '')
            table[cat_col_name].unit = catalog_header.get(f'TUNIT{col[-1]}', '')

    table.write(output_fits_path, format='fits', overwrite=True)

# %% [markdown]
# ## Process directory

# %%
def process_directory_export_objects(directory, output_directory, scale='zscale'):
    """
    Processes all FITS files in the specified directory:
    - Applies background subtraction,
    - Extracts sources from each image,
    - Saves object parameters to CSV,
    - Generates annotated visualizations.

    Parameters:
    ----------
    directory : str
        Path to the directory containing FITS files.
    output_directory : str
        Path to the directory where results (CSV/images) will be saved.
    scale : str, optional
        Image scaling mode for visualizations ('zscale', 'minmax', or 'linear').
    """
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    fits_files = [f for f in os.listdir(directory) if f.endswith('.fit') or f.endswith('.fits')]
    total_files = len(fits_files)

    for i, filename in enumerate(tqdm(fits_files, desc="Processing files", total=total_files)):
        fits_file = os.path.join(directory, filename)

        try:
            start_time = time.time()

            # Open FITS and extract data
            with fits.open(fits_file) as hdul:
                data = hdul[0].data.astype(np.float32)
                header = hdul[0].header

            # Find best background parameters and subtract background
            best_params, _ = find_best_params_balanced(fits_file, output_directory, data=data)

            if best_params is not None:
                bw, bh, fw, fh = best_params
                data_sub, bkg, header = subtract_background(fits_file, output_directory, bw, bh, fw, fh, data=data, header=header)

                if data_sub is not None:
                    # Extract objects and export to CSV
                    objects_df = extract_and_export_objects(data_sub, bkg, header, output_directory, fits_file)

                    if objects_df is not None:
                        # Visualize sources on the original image
                        plot_objects(data, objects_df, os.path.join(
                            output_directory, filename.replace(".fits", "").replace(".fit", "") + "_objs.png"), scale=scale)

            end_time = time.time()
            print(f"Processed {filename} ({i+1}/{total_files}) in {end_time - start_time:.2f} seconds.")
            print("-------------------------------------------")

        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %% [markdown]
# ## Plot parametres

# %%
# Global plotting style settings for matplotlib
plt.rcParams.update({
    'figure.figsize': (8, 6),         # Default figure size (width, height) in inches
    'figure.dpi': 100,                # Resolution for on-screen figures
    'savefig.dpi': 300,               # Resolution for saved figures
    'font.size': 12,                  # Base font size
    'font.family': 'serif',           # Font family (e.g., serif, sans-serif)
    'axes.labelsize': 14,            # Font size for axis labels
    'axes.titlesize': 14,            # Font size for axis titles
    'xtick.labelsize': 12,           # Font size for x-axis tick labels
    'ytick.labelsize': 12,           # Font size for y-axis tick labels
    'legend.fontsize': 10,           # Font size for legend text
    'lines.linewidth': 1,            # Default line width
    'lines.markersize': 6,           # Default marker size
    'axes.grid': False,              # Disable grid by default
    'grid.alpha': 0.25,              # Grid line transparency
    'grid.linestyle': '--',          # Grid line style
    'grid.color': 'gray',            # Grid line color
    'axes.axisbelow': True,          # Draw grid lines below other elements
    'image.cmap': 'viridis',         # Default colormap for image display
    'errorbar.capsize': 3,           # Length of the caps on error bars
    'legend.loc': 'best',            # Automatic legend placement
})

# %% [markdown]
# # Implementation

# %%
radius = 21.751767 #degrees taken from calculation "mean" radius for frames

# %%
fits_directory = os.getcwd() + '/data/'
output_directory = os.getcwd() + '/output/'

# %%
process_directory_export_objects(fits_directory, output_directory,scale='zscale')
