# %% [markdown]
# # Libraries

# %%
import pandas as pd  # Для работы с таблицами данных
from astropy.coordinates import SkyCoord, match_coordinates_sky
import astropy.units as u
from astropy.io import fits
from astropy.table import Table
import numpy as np

# %%
hdu = fits.open("/Volumes/astroplates2/schmidt_telescope_lc/variable_search/gsvs_catalogue/20240905_gsvs_catalogue.fits")

# %%
pd.DataFrame(hdu[1].data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58202 entries, 0 to 58201
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    58202 non-null  object
#  1   RA                      58202 non-null  float64
#  2   DEC                     58202 non-null  float64
#  3   SPECT_TYPE              58202 non-null  object
#  4   MIN_MAG_LIMIT           58202 non-null  object
#  5   MIN_MAG                 58202 non-null  float64
#  6   MAX_MAG_LIMIT           58202 non-null  object
#  7   MAX_MAG                 58202 non-null  float64
#  8   VARIABILITY_TYPE        58202 non-null  object
#  9   PERIOD_LIMIT            58202 non-null  object
#  10  PERIOD                  58202 non-null  float64
#  11  PERIOD_FLAG             58202 non-null  object
#  12  VARIABLE_STAR_NUMBER    58202 non-null  int32
#  13  VARIABLE_STAR_CPT       58202 non-null  object
#  14  NOTE_FLAG               58202 non-null  object
#  15  LII                     58202 non-null  float64
#  16  BII                     58202 non-null  float64
#  17  POSITION_FLAG           58202 non-null  object
#  18  MAX_MAG_FLAG            58202 non-null  object
#  19  MIN_MAG_FLAG            58202 non-null  object
#  20  MIN_MAG_ALT_SYS         58202 non-null  object
#  21  SEC_MIN_MAG_LIMIT       58202 non-null  object
#  22  SEC_MIN_MAG             58202 non-null  float64
#  23  SEC_MIN_MAG_FLAG        58202 non-null  object
#  24  SEC_MIN_MAG_ALT_SYS     58202 non-null  object
#  25  MAG_SYSTEM              58202 non-null  object
#  26  EPOCH                   58202 non-null  float64
#  27  EPOCH_PRECISION         58202 non-null  int16
#  28  EPOCH_FLAG              58202 non-null  object
#  29  NOVA_YEAR               58202 non-null  int16
#  30  NOVA_YEAR_FLAG          58202 non-null  object
#  31  PERIOD_PRECISION        58202 non-null  int16
#  32  PERIOD_NOTE             58202 non-null  object
#  33  RISE_ECLIPSE_TIME       58202 non-null  int16
#  34  RISE_ECLIPSE_TIME_FLAG  58202 non-null  object
#  35  ECLIPSE_VAR_NOTE        58202 non-null  object
#  36  REF_STAR                58202 non-null  object
#  37  REF_CHART               58202 non-null  object
#  38  COMMENT_FLAG            58202 non-null  object
#  39  ALT_NAME                58202 non-null  object
#  40  PM_RA                   58202 non-null  float64
#  41  PM_DEC                  58202 non-null  float64
#  42  COORDINATES_EPOCH       58202 non-null  float64
#  43  COORDINATES_EPOCH_FLAG  58202 non-null  object
#  44  REF_ASTROMETRY_FLAG     58202 non-null  object
#  45  REF_ASTROMETRY          58202 non-null  object
#  46  NEW_VARIABILITY_TYPE    58202 non-null  object
#  47  CLASS                   58202 non-null  object
# dtypes: float64(12), int16(4), int32(1), object(31)
# memory usage: 19.8+ MB

# %%
pd.read_csv("/Volumes/astroplates2/schmidt_telescope_lc/variable_search/output/parsed_from_frames/alf-Aql_25-26.07.1988_10m_47S-2-1_objects.csv")
# Out:
#           id            x            y          ra        dec           flux  \
# 0          0   291.714955     1.147484  298.333088  17.556717   24301.383437
# 1          1   955.759757     1.085002  297.250265  17.573785   20579.496563
# 2          2  1243.081584     1.213598  296.781121  17.579104   21196.886250
# 3          3  1329.267849     1.027848  296.640340  17.580836   29944.842656
# 4          4  1485.622710     1.086028  296.384875  17.583105   62737.246250
# ...      ...          ...          ...         ...        ...            ...
# 66882  13586  4245.296509  3810.802028  291.935111  11.606622  152354.268750
# 66883  13587  4346.597673  3815.558982  291.774561  11.597827   29886.789063
# 66884  13588  4536.412283  3815.375197  291.473691  11.595300   17844.298438
# 66885  13589  4739.398728  3815.948664  291.152152  11.591055   25531.759688
# 66886  13590  4747.847741  3816.269144  291.138780  11.590408   22363.413906
#
#           flux_err        mag   mag_err  flag         a         b
# 0      2753.160951 -10.964077  0.123006    16  3.134369  0.843677
# 1      2731.468197 -10.783587  0.144107    16  1.223082  0.849620
# 2      2771.144069 -10.815680  0.141942    16  1.267716  0.864745
# 3      2719.089427 -11.190805  0.098588    16  1.461335  0.920101
# 4      2739.174376 -11.993814  0.047404    16  2.058546  0.965340
# ...            ...        ...       ...   ...       ...       ...
# 66882  3021.493709 -12.957137  0.021532     0  3.113695  2.827332
# 66883  2823.059221 -11.188698  0.102557    16  1.543064  1.063053
# 66884  2872.657476 -10.628749  0.174787    16  1.454341  0.716828
# 66885  2715.921232 -11.017702  0.115494    16  0.966516  0.846687
# 66886  2621.759377 -10.873845  0.127286    16  1.384239  0.717585
#
# [66887 rows x 12 columns]

# %% [markdown]
# # Functions

# %% [markdown]
# ## Catalogue

# %%
# Функция для фильтрации гигантского каталога по координатам
def filter_catalog_by_coordinates(frame_df, catalog_df):
    """
    Ограничивает гигантский каталог по минимальным и максимальным значениям координат из таблицы объектов с кадра.
    
    Parameters:
    - frame_df: DataFrame с объектами с кадра (должен содержать столбцы 'ra' и 'dec').
    - catalog_df: Гигантский каталог в виде DataFrame (содержит 'ra' и 'dec').
    
    Returns:
    - Ограниченный каталог по координатам.
    """
    # Получение минимальных и максимальных значений координат из таблицы объектов с кадра
    ra_min, ra_max = frame_df['ra'].min(), frame_df['ra'].max()
    dec_min, dec_max = frame_df['dec'].min(), frame_df['dec'].max()

    # Ограничение гигантского каталога по этим значениям
    filtered_catalog = catalog_df[(catalog_df['ra'] >= ra_min) & (catalog_df['ra'] <= ra_max) &
                                  (catalog_df['dec'] >= dec_min) & (catalog_df['dec'] <= dec_max)]

    return filtered_catalog

#Функция для сопоставления и обработки данных
def match_objects_and_catalog(frame_df, catalog_df, output_path, unmatched_output_path, radius):
    """
    Сопоставляет объекты с кадра с каталогом и создает две таблицы:
    1. Таблица с сопоставленными объектами и добавленными колонками из каталога.
    2. Таблица с объектами, которые не нашли себе пары.
    Также добавляет столбец 'match_status', где объекты с расстоянием > radius отмечены как "uncertain".

    Parameters:
    - frame_df: DataFrame с объектами с кадра (должен содержать столбцы 'ra' и 'dec').
    - catalog_df: Ограниченный каталог (после фильтрации по координатам).
    - output_path: Путь для сохранения результирующей таблицы с сопоставленными объектами.
    - unmatched_output_path: Путь для сохранения таблицы с объектами без совпадений.
    - radius: Угловое расстояние (в угловых секундах), выше которого объект считается сомнительным.
    
    Returns:
    - Сохраняет таблицы с совпавшими и несовпавшими объектами.
    """
    # Создаем SkyCoord для объектов с кадра и каталога
    frame_coords = SkyCoord(ra=frame_df['ra'].values * u.deg, dec=frame_df['dec'].values * u.deg)
    catalog_coords = SkyCoord(ra=catalog_df['ra'].values * u.deg, dec=catalog_df['dec'].values * u.deg)

    # Выполняем кросс-матч
    idx, d2d, d3d = match_coordinates_sky(frame_coords, catalog_coords)

    # Переименовываем колонки из первой таблицы с добавлением суффикса '_frame'
    frame_df = frame_df.add_suffix('_frame')

    # Создаем таблицу с совпавшими объектами
    matched_frame = frame_df.copy()

    # Добавляем колонки из каталога с суффиксом _cat
    for col in catalog_df.columns:
        matched_frame[col + '_cat'] = catalog_df.iloc[idx][col].values

    # Добавляем столбец с разницей в координатах (в угловых секундах)
    matched_frame['coord_diff_arcsec'] = d2d.arcsec

    # Добавляем столбец 'match_status', где отмечаем объекты как "uncertain", если расстояние больше радиуса
    matched_frame['match_status'] = ['uncertain' if diff > radius else 'matched' for diff in d2d.arcsec]

    # Сохраняем таблицу с совпавшими объектами
    matched_frame.to_csv(output_path, index=False)

    # Находим объекты без совпадений
    unmatched_mask = d2d.arcsec > radius  # Условие для неподходящих объектов
    unmatched_frame = frame_df[unmatched_mask]

    # Сохраняем таблицу с объектами без совпадений
    unmatched_frame.to_csv(unmatched_output_path, index=False)

    return matched_frame, unmatched_frame

def create_fits_with_metadata(matched_frame, catalog_fits_path, output_fits_path):
    """
    Создает FITS файл с метаданными для результирующей таблицы с данными из первого и второго каталогов.
    
    Parameters:
    - matched_frame: DataFrame с совпавшими объектами (содержит объединенные данные).
    - catalog_fits_path: Путь к исходному FITS файлу гигантского каталога (для извлечения метаданных).
    - output_fits_path: Путь для сохранения результирующей таблицы в FITS формате.
    """
    
    # Конвертируем таблицу pandas в astropy Table для работы с FITS
    table = Table.from_pandas(matched_frame)
    
    # Открываем FITS файл каталога для извлечения заголовков
    with fits.open(catalog_fits_path) as hdul:
        catalog_header = hdul[1].header  # Предполагается, что данные хранятся в HDU1

    # Добавление метаданных для колонок из первой таблицы (объекты с кадра)
    metadata_frame = {
        'id_frame': {'description': 'Object identifier', 'unit': ''},
        'x_frame': {'description': 'X coordinate on image', 'unit': 'pixels'},
        'y_frame': {'description': 'Y coordinate on image', 'unit': 'pixels'},
        'ra_frame': {'description': 'Right ascension of object', 'unit': 'degrees'},
        'dec_frame': {'description': 'Declination of object', 'unit': 'degrees'},
        'flux_frame': {'description': 'Flux of object', 'unit': 'arbitrary units'},
        'flux_err_frame': {'description': 'Flux error', 'unit': 'arbitrary units'},
        'mag_frame': {'description': 'Magnitude of object', 'unit': 'mag'},
        'mag_err_frame': {'description': 'Magnitude error', 'unit': 'mag'},
        'flag_frame': {'description': 'Quality flags', 'unit': ''},
        'a_frame': {'description': 'Semi-major axis', 'unit': 'pixels'},
        'b_frame': {'description': 'Semi-minor axis', 'unit': 'pixels'},
        'coord_diff_arcsec': {'description': 'Coordinate difference between objects', 'unit': 'arcsec'}
    }

    # Применяем метаданные к первой части таблицы (данные с кадра)
    for col in metadata_frame:
        if col in table.colnames:
            table[col].description = metadata_frame[col]['description']
            table[col].unit = metadata_frame[col]['unit']
    
    # Добавляем метаданные для колонок из второго каталога, используя заголовки FITS из оригинального каталога
    for col in catalog_header:
        cat_col_name = col + '_cat'
        if cat_col_name in table.colnames:
            table[cat_col_name].description = catalog_header.comments[col]  # Используем комментарии из FITS как описание
            if catalog_header[col] == 'TUNIT':  # Проверяем наличие единиц измерения
                table[cat_col_name].unit = catalog_header[col]
            else:
                table[cat_col_name].unit = ''

    # Сохраняем таблицу в формате FITS с метаданными
    table.write(output_fits_path, format='fits', overwrite=True)

# %% [markdown]
# ## Process directory

# %%
def process_directory_export_objects(directory, output_directory, scale='zscale'):
    """
    Обрабатывает все FITS файлы в указанном каталоге, выполняя вычитание фона и извлечение объектов.
    """

        print(f"Processed {filename} ({i+1}/{total_files}) in {end_time - start_time:.2f} seconds.")
        print("-------------------------------------------")

# %% [markdown]
# ## Plot parametres

# %%
plt.rcParams.update({
    'figure.figsize': (8, 6),  # Размеры графиков
    'figure.dpi': 100,  # Разрешение графиков
    'savefig.dpi': 300,  # Разрешение сохраненных изображений
    'font.size': 12,  # Размер шрифта
    'font.family': 'serif',  # Семейство шрифтов
    'axes.labelsize': 14,  # Размер шрифта для подписей осей
    'axes.titlesize': 14,  # Размер шрифта для заголовков
    'xtick.labelsize': 12,  # Размер шрифта для подписей меток на оси X
    'ytick.labelsize': 12,  # Размер шрифта для подписей меток на оси Y
    'legend.fontsize': 10,  # Размер шрифта для легенды
    'lines.linewidth': 1,  # Толщина линий
    'lines.markersize': 6,  # Размер маркеров
    'axes.grid': False,  # Сетка на графиках
    'grid.alpha': 0.25,  # Прозрачность сетки
    'grid.linestyle': '--',  # Стиль линии сетки
    'grid.color': 'gray',  # Цвет сетки
    'axes.axisbelow': True,  # Сетка ниже данных
    'image.cmap': 'viridis',  # Цветовая карта для изображений
    'errorbar.capsize': 3,  # Размер "колпачков" на графиках ошибок
    "legend.loc": 'best', 
})

# %% [markdown]
# # Implementation

# %%
radius = 21.751767 #degrees taken from calculation "mean" radius for frames

# %%
# Укажи путь к директории с FITS файлами и директории для сохранения результатов
fits_directory = os.getcwd() + '/data/'
output_directory = os.getcwd() + '/output/'

# %%
process_directory_export_objects(fits_directory, output_directory,scale='zscale')

# %%
hdu = fits.open("/Users/ildana/astro/fai/variable_search/catalogues/gaiadr3.gaia_source_more12.8less12.9.fits")

# %%
df["phot_variable_flag"].unique()
# Out:
# array(['NOT_AVAILABLE', 'VARIABLE'], dtype=object)

# %%
hdu[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                 1380 / width of table in bytes
# NAXIS2  =               555707 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  153 / number of columns
# EXTNAME = 'gaia_user_anonymous.2024-10-04-07-12-06-889332' / table name
# TTYPE1  = 'solution_id'        / label for column 1
# TFORM1  = 'K       '           / format for column 1
# TUCD1   = 'meta.version'       / VO Unified Content Descriptor for column 1
# TTYPE2  = 'designation'        / label for column 2
# TFORM2  = '256A    '           / format for column 2
# TUCD2   = 'meta.id;meta.main'  / VO Unified Content Descriptor for column 2
# TTYPE3  = 'source_id'          / label for column 3
# TFORM3  = 'K       '           / format for column 3
# TUCD3   = 'meta.id;meta.main;meta.ref' / VO Unified Content Descriptor for colum
# TTYPE4  = 'random_index'       / label for column 4
# TFORM4  = 'K       '           / format for column 4
# TUCD4   = 'meta.code'          / VO Unified Content Descriptor for column 4
# TTYPE5  = 'ref_epoch'          / label for column 5
# TFORM5  = 'D       '           / format for column 5
# TUNIT5  = 'yr      '           / units for column 5
# TUCD5   = 'meta.ref;time.epoch' / VO Unified Content Descriptor for column 5
# TTYPE6  = 'ra      '           / label for column 6
# TFORM6  = 'D       '           / format for column 6
# TUNIT6  = 'deg     '           / units for column 6
# TUCD6   = 'pos.eq.ra;meta.main' / VO Unified Content Descriptor for column 6
# TTYPE7  = 'ra_error'           / label for column 7
# TFORM7  = 'E       '           / format for column 7
# TUNIT7  = 'mas     '           / units for column 7
# TUCD7   = 'stat.error;pos.eq.ra' / VO Unified Content Descriptor for column 7
# TTYPE8  = 'dec     '           / label for column 8
# TFORM8  = 'D       '           / format for column 8
# TUNIT8  = 'deg     '           / units for column 8
# TUCD8   = 'pos.eq.dec;meta.main' / VO Unified Content Descriptor for column 8
# TTYPE9  = 'dec_error'          / label for column 9
# TFORM9  = 'E       '           / format for column 9
# TUNIT9  = 'mas     '           / units for column 9
# TUCD9   = 'stat.error;pos.eq.dec' / VO Unified Content Descriptor for column 9
# TTYPE10 = 'parallax'           / label for column 10
# TFORM10 = 'D       '           / format for column 10
# TUNIT10 = 'mas     '           / units for column 10
# TUCD10  = 'pos.parallax.trig'  / VO Unified Content Descriptor for column 10
# TTYPE11 = 'parallax_error'     / label for column 11
# TFORM11 = 'E       '           / format for column 11
# TUNIT11 = 'mas     '           / units for column 11
# TUCD11  = 'stat.error;pos.parallax.trig' / VO Unified Content Descriptor for col
# TTYPE12 = 'parallax_over_error' / label for column 12
# TFORM12 = 'E       '           / format for column 12
# TUCD12  = 'stat.snr;pos.parallax.trig' / VO Unified Content Descriptor for colum
# TTYPE13 = 'pm      '           / label for column 13
# TFORM13 = 'E       '           / format for column 13
# TUNIT13 = 'mas.yr**-1'         / units for column 13
# TUCD13  = 'pos.pm;pos.eq'      / VO Unified Content Descriptor for column 13
# TTYPE14 = 'pmra    '           / label for column 14
# TFORM14 = 'D       '           / format for column 14
# TUNIT14 = 'mas.yr**-1'         / units for column 14
# TUCD14  = 'pos.pm;pos.eq.ra'   / VO Unified Content Descriptor for column 14
# TTYPE15 = 'pmra_error'         / label for column 15
# TFORM15 = 'E       '           / format for column 15
# TUNIT15 = 'mas.yr**-1'         / units for column 15
# TUCD15  = 'stat.error;pos.pm;pos.eq.ra' / VO Unified Content Descriptor for colu
# TTYPE16 = 'pmdec   '           / label for column 16
# TFORM16 = 'D       '           / format for column 16
# TUNIT16 = 'mas.yr**-1'         / units for column 16
# TUCD16  = 'pos.pm;pos.eq.dec'  / VO Unified Content Descriptor for column 16
# TTYPE17 = 'pmdec_error'        / label for column 17
# TFORM17 = 'E       '           / format for column 17
# TUNIT17 = 'mas.yr**-1'         / units for column 17
# TUCD17  = 'stat.error;pos.pm;pos.eq.dec' / VO Unified Content Descriptor for col
# TTYPE18 = 'ra_dec_corr'        / label for column 18
# TFORM18 = 'E       '           / format for column 18
# TUCD18  = 'stat.correlation'   / VO Unified Content Descriptor for column 18
# TTYPE19 = 'ra_parallax_corr'   / label for column 19
# TFORM19 = 'E       '           / format for column 19
# TUCD19  = 'stat.correlation'   / VO Unified Content Descriptor for column 19
# TTYPE20 = 'ra_pmra_corr'       / label for column 20
# TFORM20 = 'E       '           / format for column 20
# TUCD20  = 'stat.correlation'   / VO Unified Content Descriptor for column 20
# TTYPE21 = 'ra_pmdec_corr'      / label for column 21
# TFORM21 = 'E       '           / format for column 21
# TUCD21  = 'stat.correlation'   / VO Unified Content Descriptor for column 21
# TTYPE22 = 'dec_parallax_corr'  / label for column 22
# TFORM22 = 'E       '           / format for column 22
# TUCD22  = 'stat.correlation'   / VO Unified Content Descriptor for column 22
# TTYPE23 = 'dec_pmra_corr'      / label for column 23
# TFORM23 = 'E       '           / format for column 23
# TUCD23  = 'stat.correlation'   / VO Unified Content Descriptor for column 23
# TTYPE24 = 'dec_pmdec_corr'     / label for column 24
# TFORM24 = 'E       '           / format for column 24
# TUCD24  = 'stat.correlation'   / VO Unified Content Descriptor for column 24
# TTYPE25 = 'parallax_pmra_corr' / label for column 25
# TFORM25 = 'E       '           / format for column 25
# TUCD25  = 'stat.correlation'   / VO Unified Content Descriptor for column 25
# TTYPE26 = 'parallax_pmdec_corr' / label for column 26
# TFORM26 = 'E       '           / format for column 26
# TUCD26  = 'stat.correlation'   / VO Unified Content Descriptor for column 26
# TTYPE27 = 'pmra_pmdec_corr'    / label for column 27
# TFORM27 = 'E       '           / format for column 27
# TUCD27  = 'stat.correlation'   / VO Unified Content Descriptor for column 27
# TTYPE28 = 'astrometric_n_obs_al' / label for column 28
# TFORM28 = 'I       '           / format for column 28
# TUCD28  = 'meta.number'        / VO Unified Content Descriptor for column 28
# TTYPE29 = 'astrometric_n_obs_ac' / label for column 29
# TFORM29 = 'I       '           / format for column 29
# TUCD29  = 'meta.number'        / VO Unified Content Descriptor for column 29
# TTYPE30 = 'astrometric_n_good_obs_al' / label for column 30
# TFORM30 = 'I       '           / format for column 30
# TUCD30  = 'meta.number'        / VO Unified Content Descriptor for column 30
# TTYPE31 = 'astrometric_n_bad_obs_al' / label for column 31
# TFORM31 = 'I       '           / format for column 31
# TUCD31  = 'meta.number'        / VO Unified Content Descriptor for column 31
# TTYPE32 = 'astrometric_gof_al' / label for column 32
# TFORM32 = 'E       '           / format for column 32
# TUCD32  = 'stat.fit.goodness'  / VO Unified Content Descriptor for column 32
# TTYPE33 = 'astrometric_chi2_al' / label for column 33
# TFORM33 = 'E       '           / format for column 33
# TUCD33  = 'stat.fit.chi2'      / VO Unified Content Descriptor for column 33
# TTYPE34 = 'astrometric_excess_noise' / label for column 34
# TFORM34 = 'E       '           / format for column 34
# TUNIT34 = 'mas     '           / units for column 34
# TUCD34  = 'stat.value'         / VO Unified Content Descriptor for column 34
# TTYPE35 = 'astrometric_excess_noise_sig' / label for column 35
# TFORM35 = 'E       '           / format for column 35
# TUCD35  = 'stat.value'         / VO Unified Content Descriptor for column 35
# TTYPE36 = 'astrometric_params_solved' / label for column 36
# TFORM36 = 'I       '           / format for column 36
# TUCD36  = 'meta.number'        / VO Unified Content Descriptor for column 36
# TTYPE37 = 'astrometric_primary_flag' / label for column 37
# TFORM37 = 'L       '           / format for column 37
# TUCD37  = 'meta.code'          / VO Unified Content Descriptor for column 37
# TTYPE38 = 'nu_eff_used_in_astrometry' / label for column 38
# TFORM38 = 'E       '           / format for column 38
# TUNIT38 = 'um**-1  '           / units for column 38
# TUCD38  = 'em.wavenumber'      / VO Unified Content Descriptor for column 38
# TTYPE39 = 'pseudocolour'       / label for column 39
# TFORM39 = 'E       '           / format for column 39
# TUNIT39 = 'um**-1  '           / units for column 39
# TUCD39  = 'em.wavenumber'      / VO Unified Content Descriptor for column 39
# TTYPE40 = 'pseudocolour_error' / label for column 40
# TFORM40 = 'E       '           / format for column 40
# TUNIT40 = 'um**-1  '           / units for column 40
# TUCD40  = 'stat.error;em.wavenumber' / VO Unified Content Descriptor for column
# TTYPE41 = 'ra_pseudocolour_corr' / label for column 41
# TFORM41 = 'E       '           / format for column 41
# TUCD41  = 'stat.correlation;em.wavenumber;pos.eq.ra' / VO Unified Content Descri
# TTYPE42 = 'dec_pseudocolour_corr' / label for column 42
# TFORM42 = 'E       '           / format for column 42
# TUCD42  = 'stat.correlation;em.wavenumber;pos.eq.dec' / VO Unified Content Descr
# TTYPE43 = 'parallax_pseudocolour_corr' / label for column 43
# TFORM43 = 'E       '           / format for column 43
# TUCD43  = 'stat.correlation;em.wavenumber;pos.parallax' / VO Unified Content Des
# TTYPE44 = 'pmra_pseudocolour_corr' / label for column 44
# TFORM44 = 'E       '           / format for column 44
# TUCD44  = 'stat.correlation;em.wavenumber;pos.pm;pos.eq.ra' / VO Unified Content
# TTYPE45 = 'pmdec_pseudocolour_corr' / label for column 45
# TFORM45 = 'E       '           / format for column 45
# TUCD45  = 'stat.correlation;em.wavenumber;pos.pm;pos.eq.dec' / VO Unified Conten
# TTYPE46 = 'astrometric_matched_transits' / label for column 46
# TFORM46 = 'I       '           / format for column 46
# TUCD46  = 'meta.number'        / VO Unified Content Descriptor for column 46
# TTYPE47 = 'visibility_periods_used' / label for column 47
# TFORM47 = 'I       '           / format for column 47
# TUCD47  = 'meta.number'        / VO Unified Content Descriptor for column 47
# TTYPE48 = 'astrometric_sigma5d_max' / label for column 48
# TFORM48 = 'E       '           / format for column 48
# TUNIT48 = 'mas     '           / units for column 48
# TUCD48  = 'stat;pos.errorEllipse' / VO Unified Content Descriptor for column 48
# TTYPE49 = 'matched_transits'   / label for column 49
# TFORM49 = 'I       '           / format for column 49
# TUCD49  = 'meta.number'        / VO Unified Content Descriptor for column 49
# TTYPE50 = 'new_matched_transits' / label for column 50
# TFORM50 = 'I       '           / format for column 50
# TUCD50  = 'meta.number'        / VO Unified Content Descriptor for column 50
# TTYPE51 = 'matched_transits_removed' / label for column 51
# TFORM51 = 'I       '           / format for column 51
# TUCD51  = 'meta.number'        / VO Unified Content Descriptor for column 51
# TTYPE52 = 'ipd_gof_harmonic_amplitude' / label for column 52
# TFORM52 = 'E       '           / format for column 52
# TUCD52  = 'stat.value'         / VO Unified Content Descriptor for column 52
# TTYPE53 = 'ipd_gof_harmonic_phase' / label for column 53
# TFORM53 = 'E       '           / format for column 53
# TUNIT53 = 'deg     '           / units for column 53
# TUCD53  = 'pos.posAng;stat.value' / VO Unified Content Descriptor for column 53
# TTYPE54 = 'ipd_frac_multi_peak' / label for column 54
# TFORM54 = 'I       '           / format for column 54
# TUCD54  = 'stat.value'         / VO Unified Content Descriptor for column 54
# TTYPE55 = 'ipd_frac_odd_win'   / label for column 55
# TFORM55 = 'I       '           / format for column 55
# TUCD55  = 'stat.value'         / VO Unified Content Descriptor for column 55
# TTYPE56 = 'ruwe    '           / label for column 56
# TFORM56 = 'E       '           / format for column 56
# TUCD56  = 'stat.error'         / VO Unified Content Descriptor for column 56
# TTYPE57 = 'scan_direction_strength_k1' / label for column 57
# TFORM57 = 'E       '           / format for column 57
# TUCD57  = 'stat.value'         / VO Unified Content Descriptor for column 57
# TTYPE58 = 'scan_direction_strength_k2' / label for column 58
# TFORM58 = 'E       '           / format for column 58
# TUCD58  = 'stat.value'         / VO Unified Content Descriptor for column 58
# TTYPE59 = 'scan_direction_strength_k3' / label for column 59
# TFORM59 = 'E       '           / format for column 59
# TUCD59  = 'stat.value'         / VO Unified Content Descriptor for column 59
# TTYPE60 = 'scan_direction_strength_k4' / label for column 60
# TFORM60 = 'E       '           / format for column 60
# TUCD60  = 'stat.value'         / VO Unified Content Descriptor for column 60
# TTYPE61 = 'scan_direction_mean_k1' / label for column 61
# TFORM61 = 'E       '           / format for column 61
# TUNIT61 = 'deg     '           / units for column 61
# TUCD61  = 'pos.posAng;stat.mean' / VO Unified Content Descriptor for column 61
# TTYPE62 = 'scan_direction_mean_k2' / label for column 62
# TFORM62 = 'E       '           / format for column 62
# TUNIT62 = 'deg     '           / units for column 62
# TUCD62  = 'pos.posAng;stat.mean' / VO Unified Content Descriptor for column 62
# TTYPE63 = 'scan_direction_mean_k3' / label for column 63
# TFORM63 = 'E       '           / format for column 63
# TUNIT63 = 'deg     '           / units for column 63
# TUCD63  = 'pos.posAng;stat.mean' / VO Unified Content Descriptor for column 63
# TTYPE64 = 'scan_direction_mean_k4' / label for column 64
# TFORM64 = 'E       '           / format for column 64
# TUNIT64 = 'deg     '           / units for column 64
# TUCD64  = 'pos.posAng;stat.mean' / VO Unified Content Descriptor for column 64
# TTYPE65 = 'duplicated_source'  / label for column 65
# TFORM65 = 'L       '           / format for column 65
# TUCD65  = 'meta.code.status'   / VO Unified Content Descriptor for column 65
# TTYPE66 = 'phot_g_n_obs'       / label for column 66
# TFORM66 = 'I       '           / format for column 66
# TUCD66  = 'meta.number'        / VO Unified Content Descriptor for column 66
# TTYPE67 = 'phot_g_mean_flux'   / label for column 67
# TFORM67 = 'D       '           / format for column 67
# TUNIT67 = '"electron".s**-1'   / units for column 67
# TUCD67  = 'phot.flux;em.opt'   / VO Unified Content Descriptor for column 67
# TTYPE68 = 'phot_g_mean_flux_error' / label for column 68
# TFORM68 = 'E       '           / format for column 68
# TUNIT68 = '"electron".s**-1'   / units for column 68
# TUCD68  = 'stat.error;phot.flux;em.opt' / VO Unified Content Descriptor for colu
# TTYPE69 = 'phot_g_mean_flux_over_error' / label for column 69
# TFORM69 = 'E       '           / format for column 69
# TUCD69  = 'stat.snr;phot.flux;em.opt' / VO Unified Content Descriptor for column
# TTYPE70 = 'phot_g_mean_mag'    / label for column 70
# TFORM70 = 'E       '           / format for column 70
# TUNIT70 = 'mag     '           / units for column 70
# TUCD70  = 'phot.mag;em.opt'    / VO Unified Content Descriptor for column 70
# TTYPE71 = 'phot_bp_n_obs'      / label for column 71
# TFORM71 = 'I       '           / format for column 71
# TUCD71  = 'meta.number'        / VO Unified Content Descriptor for column 71
# TTYPE72 = 'phot_bp_mean_flux'  / label for column 72
# TFORM72 = 'D       '           / format for column 72
# TUNIT72 = '"electron".s**-1'   / units for column 72
# TUCD72  = 'phot.flux;em.opt.B' / VO Unified Content Descriptor for column 72
# TTYPE73 = 'phot_bp_mean_flux_error' / label for column 73
# TFORM73 = 'E       '           / format for column 73
# TUNIT73 = '"electron".s**-1'   / units for column 73
# TUCD73  = 'stat.error;phot.flux;em.opt.B' / VO Unified Content Descriptor for co
# TTYPE74 = 'phot_bp_mean_flux_over_error' / label for column 74
# TFORM74 = 'E       '           / format for column 74
# TUCD74  = 'stat.snr;phot.flux;em.opt.B' / VO Unified Content Descriptor for colu
# TTYPE75 = 'phot_bp_mean_mag'   / label for column 75
# TFORM75 = 'E       '           / format for column 75
# TUNIT75 = 'mag     '           / units for column 75
# TUCD75  = 'phot.mag;em.opt.B'  / VO Unified Content Descriptor for column 75
# TTYPE76 = 'phot_rp_n_obs'      / label for column 76
# TFORM76 = 'I       '           / format for column 76
# TUCD76  = 'meta.number'        / VO Unified Content Descriptor for column 76
# TTYPE77 = 'phot_rp_mean_flux'  / label for column 77
# TFORM77 = 'D       '           / format for column 77
# TUNIT77 = '"electron".s**-1'   / units for column 77
# TUCD77  = 'phot.flux;em.opt.R' / VO Unified Content Descriptor for column 77
# TTYPE78 = 'phot_rp_mean_flux_error' / label for column 78
# TFORM78 = 'E       '           / format for column 78
# TUNIT78 = '"electron".s**-1'   / units for column 78
# TUCD78  = 'stat.error;phot.flux;em.opt.R' / VO Unified Content Descriptor for co
# TTYPE79 = 'phot_rp_mean_flux_over_error' / label for column 79
# TFORM79 = 'E       '           / format for column 79
# TUCD79  = 'stat.snr;phot.flux;em.opt.R' / VO Unified Content Descriptor for colu
# TTYPE80 = 'phot_rp_mean_mag'   / label for column 80
# TFORM80 = 'E       '           / format for column 80
# TUNIT80 = 'mag     '           / units for column 80
# TUCD80  = 'phot.mag;em.opt.R'  / VO Unified Content Descriptor for column 80
# TTYPE81 = 'phot_bp_rp_excess_factor' / label for column 81
# TFORM81 = 'E       '           / format for column 81
# TUCD81  = 'arith.factor;phot.flux;em.opt' / VO Unified Content Descriptor for co
# TTYPE82 = 'phot_bp_n_contaminated_transits' / label for column 82
# TFORM82 = 'I       '           / format for column 82
# TNULL82 =               -32768 / blank value for column 82
# TUCD82  = 'meta.number'        / VO Unified Content Descriptor for column 82
# TTYPE83 = 'phot_bp_n_blended_transits' / label for column 83
# TFORM83 = 'I       '           / format for column 83
# TNULL83 =               -32768 / blank value for column 83
# TUCD83  = 'meta.number'        / VO Unified Content Descriptor for column 83
# TTYPE84 = 'phot_rp_n_contaminated_transits' / label for column 84
# TFORM84 = 'I       '           / format for column 84
# TNULL84 =               -32768 / blank value for column 84
# TUCD84  = 'meta.number'        / VO Unified Content Descriptor for column 84
# TTYPE85 = 'phot_rp_n_blended_transits' / label for column 85
# TFORM85 = 'I       '           / format for column 85
# TNULL85 =               -32768 / blank value for column 85
# TUCD85  = 'meta.number'        / VO Unified Content Descriptor for column 85
# TTYPE86 = 'phot_proc_mode'     / label for column 86
# TFORM86 = 'I       '           / format for column 86
# TUCD86  = 'meta.code'          / VO Unified Content Descriptor for column 86
# TTYPE87 = 'bp_rp   '           / label for column 87
# TFORM87 = 'E       '           / format for column 87
# TUNIT87 = 'mag     '           / units for column 87
# TUCD87  = 'phot.color;em.opt.B;em.opt.R' / VO Unified Content Descriptor for col
# TTYPE88 = 'bp_g    '           / label for column 88
# TFORM88 = 'E       '           / format for column 88
# TUNIT88 = 'mag     '           / units for column 88
# TUCD88  = 'phot.color;em.opt.B;em.opt' / VO Unified Content Descriptor for colum
# TTYPE89 = 'g_rp    '           / label for column 89
# TFORM89 = 'E       '           / format for column 89
# TUNIT89 = 'mag     '           / units for column 89
# TUCD89  = 'phot.color;em.opt;em.opt.R' / VO Unified Content Descriptor for colum
# TTYPE90 = 'radial_velocity'    / label for column 90
# TFORM90 = 'E       '           / format for column 90
# TUNIT90 = 'km.s**-1'           / units for column 90
# TUCD90  = 'spect.dopplerVeloc.opt;em.opt.I' / VO Unified Content Descriptor for
# TTYPE91 = 'radial_velocity_error' / label for column 91
# TFORM91 = 'E       '           / format for column 91
# TUNIT91 = 'km.s**-1'           / units for column 91
# TUCD91  = 'stat.error;spect.dopplerVeloc.opt;em.opt.I' / VO Unified Content Desc
# TTYPE92 = 'rv_method_used'     / label for column 92
# TFORM92 = 'I       '           / format for column 92
# TNULL92 =               -32768 / blank value for column 92
# TUCD92  = 'meta.code.class'    / VO Unified Content Descriptor for column 92
# TTYPE93 = 'rv_nb_transits'     / label for column 93
# TFORM93 = 'I       '           / format for column 93
# TNULL93 =               -32768 / blank value for column 93
# TUCD93  = 'meta.number'        / VO Unified Content Descriptor for column 93
# TTYPE94 = 'rv_nb_deblended_transits' / label for column 94
# TFORM94 = 'I       '           / format for column 94
# TNULL94 =               -32768 / blank value for column 94
# TUCD94  = 'meta.number'        / VO Unified Content Descriptor for column 94
# TTYPE95 = 'rv_visibility_periods_used' / label for column 95
# TFORM95 = 'I       '           / format for column 95
# TNULL95 =               -32768 / blank value for column 95
# TUCD95  = 'meta.number'        / VO Unified Content Descriptor for column 95
# TTYPE96 = 'rv_expected_sig_to_noise' / label for column 96
# TFORM96 = 'E       '           / format for column 96
# TUCD96  = 'stat.snr'           / VO Unified Content Descriptor for column 96
# TTYPE97 = 'rv_renormalised_gof' / label for column 97
# TFORM97 = 'E       '           / format for column 97
# TUCD97  = 'stat.fit.goodness'  / VO Unified Content Descriptor for column 97
# TTYPE98 = 'rv_chisq_pvalue'    / label for column 98
# TFORM98 = 'E       '           / format for column 98
# TUCD98  = 'stat.fit.param'     / VO Unified Content Descriptor for column 98
# TTYPE99 = 'rv_time_duration'   / label for column 99
# TFORM99 = 'E       '           / format for column 99
# TUNIT99 = 'd       '           / units for column 99
# TUCD99  = 'time.duration'      / VO Unified Content Descriptor for column 99
# TTYPE100= 'rv_amplitude_robust' / label for column 100
# TFORM100= 'E       '           / format for column 100
# TUNIT100= 'km.s**-1'           / units for column 100
# TUCD100 = 'stat.error;spect.dopplerVeloc.opt;em.opt.I' / VO Unified Content Desc
# TTYPE101= 'rv_template_teff'   / label for column 101
# TFORM101= 'E       '           / format for column 101
# TUNIT101= 'K       '           / units for column 101
# TUCD101 = 'stat.fit.param'     / VO Unified Content Descriptor for column 101
# TTYPE102= 'rv_template_logg'   / label for column 102
# TFORM102= 'E       '           / format for column 102
# TUNIT102= 'log(cm.s**-2)'      / units for column 102
# TUCD102 = 'stat.fit.param'     / VO Unified Content Descriptor for column 102
# TTYPE103= 'rv_template_fe_h'   / label for column 103
# TFORM103= 'E       '           / format for column 103
# TUNIT103= '"dex"   '           / units for column 103
# TUCD103 = 'stat.fit.param'     / VO Unified Content Descriptor for column 103
# TTYPE104= 'rv_atm_param_origin' / label for column 104
# TFORM104= 'I       '           / format for column 104
# TNULL104=               -32768 / blank value for column 104
# TUCD104 = 'meta.code.class'    / VO Unified Content Descriptor for column 104
# TTYPE105= 'vbroad  '           / label for column 105
# TFORM105= 'E       '           / format for column 105
# TUNIT105= 'km.s**-1'           / units for column 105
# TUCD105 = 'spect.dopplerVeloc.opt;em.opt.I' / VO Unified Content Descriptor for
# TTYPE106= 'vbroad_error'       / label for column 106
# TFORM106= 'E       '           / format for column 106
# TUNIT106= 'km.s**-1'           / units for column 106
# TUCD106 = 'stat.error;spect.dopplerVeloc.opt;em.opt.I' / VO Unified Content Desc
# TTYPE107= 'vbroad_nb_transits' / label for column 107
# TFORM107= 'I       '           / format for column 107
# TNULL107=               -32768 / blank value for column 107
# TUCD107 = 'meta.number'        / VO Unified Content Descriptor for column 107
# TTYPE108= 'grvs_mag'           / label for column 108
# TFORM108= 'E       '           / format for column 108
# TUNIT108= 'mag     '           / units for column 108
# TUCD108 = 'phot.mag;em.opt'    / VO Unified Content Descriptor for column 108
# TTYPE109= 'grvs_mag_error'     / label for column 109
# TFORM109= 'E       '           / format for column 109
# TUNIT109= 'mag     '           / units for column 109
# TUCD109 = 'stat.error;phot.mag;em.opt' / VO Unified Content Descriptor for colum
# TTYPE110= 'grvs_mag_nb_transits' / label for column 110
# TFORM110= 'I       '           / format for column 110
# TNULL110=               -32768 / blank value for column 110
# TUCD110 = 'meta.number'        / VO Unified Content Descriptor for column 110
# TTYPE111= 'rvs_spec_sig_to_noise' / label for column 111
# TFORM111= 'E       '           / format for column 111
# TUCD111 = 'stat.snr'           / VO Unified Content Descriptor for column 111
# TTYPE112= 'phot_variable_flag' / label for column 112
# TFORM112= '256A    '           / format for column 112
# TUCD112 = 'meta.code;src.var'  / VO Unified Content Descriptor for column 112
# TTYPE113= 'l       '           / label for column 113
# TFORM113= 'D       '           / format for column 113
# TUNIT113= 'deg     '           / units for column 113
# TUCD113 = 'pos.galactic.lon'   / VO Unified Content Descriptor for column 113
# TTYPE114= 'b       '           / label for column 114
# TFORM114= 'D       '           / format for column 114
# TUNIT114= 'deg     '           / units for column 114
# TUCD114 = 'pos.galactic.lat'   / VO Unified Content Descriptor for column 114
# TTYPE115= 'ecl_lon '           / label for column 115
# TFORM115= 'D       '           / format for column 115
# TUNIT115= 'deg     '           / units for column 115
# TUCD115 = 'pos.ecliptic.lon'   / VO Unified Content Descriptor for column 115
# TTYPE116= 'ecl_lat '           / label for column 116
# TFORM116= 'D       '           / format for column 116
# TUNIT116= 'deg     '           / units for column 116
# TUCD116 = 'pos.ecliptic.lat'   / VO Unified Content Descriptor for column 116
# TTYPE117= 'in_qso_candidates'  / label for column 117
# TFORM117= 'L       '           / format for column 117
# TUCD117 = 'meta.code.status'   / VO Unified Content Descriptor for column 117
# TTYPE118= 'in_galaxy_candidates' / label for column 118
# TFORM118= 'L       '           / format for column 118
# TUCD118 = 'meta.code.status'   / VO Unified Content Descriptor for column 118
# TTYPE119= 'non_single_star'    / label for column 119
# TFORM119= 'I       '           / format for column 119
# TUCD119 = 'meta.code.status'   / VO Unified Content Descriptor for column 119
# TTYPE120= 'has_xp_continuous'  / label for column 120
# TFORM120= 'L       '           / format for column 120
# TUCD120 = 'meta.code.status'   / VO Unified Content Descriptor for column 120
# TTYPE121= 'has_xp_sampled'     / label for column 121
# TFORM121= 'L       '           / format for column 121
# TUCD121 = 'meta.code.status'   / VO Unified Content Descriptor for column 121
# TTYPE122= 'has_rvs '           / label for column 122
# TFORM122= 'L       '           / format for column 122
# TUCD122 = 'meta.code.status'   / VO Unified Content Descriptor for column 122
# TTYPE123= 'has_epoch_photometry' / label for column 123
# TFORM123= 'L       '           / format for column 123
# TUCD123 = 'meta.code.status'   / VO Unified Content Descriptor for column 123
# TTYPE124= 'has_epoch_rv'       / label for column 124
# TFORM124= 'L       '           / format for column 124
# TUCD124 = 'meta.code.status'   / VO Unified Content Descriptor for column 124
# TTYPE125= 'has_mcmc_gspphot'   / label for column 125
# TFORM125= 'L       '           / format for column 125
# TUCD125 = 'meta.code.status'   / VO Unified Content Descriptor for column 125
# TTYPE126= 'has_mcmc_msc'       / label for column 126
# TFORM126= 'L       '           / format for column 126
# TUCD126 = 'meta.code.status'   / VO Unified Content Descriptor for column 126
# TTYPE127= 'in_andromeda_survey' / label for column 127
# TFORM127= 'L       '           / format for column 127
# TUCD127 = 'meta.code.status'   / VO Unified Content Descriptor for column 127
# TTYPE128= 'classprob_dsc_combmod_quasar' / label for column 128
# TFORM128= 'E       '           / format for column 128
# TUCD128 = 'stat.probability'   / VO Unified Content Descriptor for column 128
# TTYPE129= 'classprob_dsc_combmod_galaxy' / label for column 129
# TFORM129= 'E       '           / format for column 129
# TUCD129 = 'stat.probability'   / VO Unified Content Descriptor for column 129
# TTYPE130= 'classprob_dsc_combmod_star' / label for column 130
# TFORM130= 'E       '           / format for column 130
# TUCD130 = 'stat.probability'   / VO Unified Content Descriptor for column 130
# TTYPE131= 'teff_gspphot'       / label for column 131
# TFORM131= 'E       '           / format for column 131
# TUNIT131= 'K       '           / units for column 131
# TUCD131 = 'phys.temperature.effective' / VO Unified Content Descriptor for colum
# TTYPE132= 'teff_gspphot_lower' / label for column 132
# TFORM132= 'E       '           / format for column 132
# TUNIT132= 'K       '           / units for column 132
# TUCD132 = 'phys.temperature.effective;stat.min' / VO Unified Content Descriptor
# TTYPE133= 'teff_gspphot_upper' / label for column 133
# TFORM133= 'E       '           / format for column 133
# TUNIT133= 'K       '           / units for column 133
# TUCD133 = 'phys.temperature.effective;stat.max' / VO Unified Content Descriptor
# TTYPE134= 'logg_gspphot'       / label for column 134
# TFORM134= 'E       '           / format for column 134
# TUNIT134= 'log(cm.s**-2)'      / units for column 134
# TUCD134 = 'phys.gravity'       / VO Unified Content Descriptor for column 134
# TTYPE135= 'logg_gspphot_lower' / label for column 135
# TFORM135= 'E       '           / format for column 135
# TUNIT135= 'log(cm.s**-2)'      / units for column 135
# TUCD135 = 'phys.gravity;stat.min' / VO Unified Content Descriptor for column 135
# TTYPE136= 'logg_gspphot_upper' / label for column 136
# TFORM136= 'E       '           / format for column 136
# TUNIT136= 'log(cm.s**-2)'      / units for column 136
# TUCD136 = 'phys.gravity;stat.max' / VO Unified Content Descriptor for column 136
# TTYPE137= 'mh_gspphot'         / label for column 137
# TFORM137= 'E       '           / format for column 137
# TUNIT137= '"dex"   '           / units for column 137
# TUCD137 = 'phys.abund.Z'       / VO Unified Content Descriptor for column 137
# TTYPE138= 'mh_gspphot_lower'   / label for column 138
# TFORM138= 'E       '           / format for column 138
# TUNIT138= '"dex"   '           / units for column 138
# TUCD138 = 'phys.abund.Z;stat.min' / VO Unified Content Descriptor for column 138
# TTYPE139= 'mh_gspphot_upper'   / label for column 139
# TFORM139= 'E       '           / format for column 139
# TUNIT139= '"dex"   '           / units for column 139
# TUCD139 = 'phys.abund.Z;stat.max' / VO Unified Content Descriptor for column 139
# TTYPE140= 'distance_gspphot'   / label for column 140
# TFORM140= 'E       '           / format for column 140
# TUNIT140= 'pc      '           / units for column 140
# TUCD140 = 'pos.distance;pos.eq' / VO Unified Content Descriptor for column 140
# TTYPE141= 'distance_gspphot_lower' / label for column 141
# TFORM141= 'E       '           / format for column 141
# TUNIT141= 'pc      '           / units for column 141
# TUCD141 = 'pos.distance;pos.eq' / VO Unified Content Descriptor for column 141
# TTYPE142= 'distance_gspphot_upper' / label for column 142
# TFORM142= 'E       '           / format for column 142
# TUNIT142= 'pc      '           / units for column 142
# TUCD142 = 'pos.distance;pos.eq' / VO Unified Content Descriptor for column 142
# TTYPE143= 'azero_gspphot'      / label for column 143
# TFORM143= 'E       '           / format for column 143
# TUNIT143= 'mag     '           / units for column 143
# TUCD143 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE144= 'azero_gspphot_lower' / label for column 144
# TFORM144= 'E       '           / format for column 144
# TUNIT144= 'mag     '           / units for column 144
# TUCD144 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE145= 'azero_gspphot_upper' / label for column 145
# TFORM145= 'E       '           / format for column 145
# TUNIT145= 'mag     '           / units for column 145
# TUCD145 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE146= 'ag_gspphot'         / label for column 146
# TFORM146= 'E       '           / format for column 146
# TUNIT146= 'mag     '           / units for column 146
# TUCD146 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE147= 'ag_gspphot_lower'   / label for column 147
# TFORM147= 'E       '           / format for column 147
# TUNIT147= 'mag     '           / units for column 147
# TUCD147 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE148= 'ag_gspphot_upper'   / label for column 148
# TFORM148= 'E       '           / format for column 148
# TUNIT148= 'mag     '           / units for column 148
# TUCD148 = 'phys.absorption;em.opt' / VO Unified Content Descriptor for column 14
# TTYPE149= 'ebpminrp_gspphot'   / label for column 149
# TFORM149= 'E       '           / format for column 149
# TUNIT149= 'mag     '           / units for column 149
# TUCD149 = 'phot.color.excess'  / VO Unified Content Descriptor for column 149
# TTYPE150= 'ebpminrp_gspphot_lower' / label for column 150
# TFORM150= 'E       '           / format for column 150
# TUNIT150= 'mag     '           / units for column 150
# TUCD150 = 'phot.color.excess;stat.min' / VO Unified Content Descriptor for colum
# TTYPE151= 'ebpminrp_gspphot_upper' / label for column 151
# TFORM151= 'E       '           / format for column 151
# TUNIT151= 'mag     '           / units for column 151
# TUCD151 = 'phot.color.excess;stat.max' / VO Unified Content Descriptor for colum
# TTYPE152= 'libname_gspphot'    / label for column 152
# TFORM152= '256A    '           / format for column 152
# TUCD152 = 'meta.note'          / VO Unified Content Descriptor for column 152
# TTYPE153= 'pos     '           / label for column 153
# TFORM153= '44A     '           / format for column 153
# TUNIT153= '[rad, rad]'         / units for column 153
# TUCD153 = '(pos.eq.ra,pos.eq.dec)' / VO Unified Content Descriptor for column 15
# DATE-HDU= '2024-10-04T08:11:28' / Date of HDU creation (UTC)
# STILVERS= '4.3     '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.UnifiedFitsTableWriter' / STIL Author class
